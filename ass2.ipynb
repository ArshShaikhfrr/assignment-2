# %%
def add_book(title, author, genre):
    return (title, author, genre)

def add_to_library(book, library, book_set):
    if book not in book_set:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} {book[2]} added to the library.")
    else:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} already exists in the library.")
        return library

def remove_from_library(title, library, book_set):
    for book in library:
        if book[0] == title:
            library.remove(book)
            book_set.remove(book)
            print(f"Book '{title}' removed from the library.")
            return
    print(f"Book '{title}' not found in the library.")

def search_books(search_term, library):
    results = [book for book in library if search_term.lower() in book[0].lower() or search_term.lower() in book[1].lower()]
    return results

def list_books(library):
    print("Entering in Library:")
    for i in range(4):
        library[i]
        print(f"Title: {library[0]}, Author: {library[1]}, Genre: {library[2]}")
    
    print("No books in the library.")

def categorize_books(book, library, book_set):
    genre_dict = {}
    for book in library:
        genre = book[2]
        if genre not in genre_dict:
            genre_dict['genre'] = []
        genre_dict['genre'].append(book)
    return genre_dict

def check_dup(library):
    repeat=()
    for i in range(3):
        if library[i] == library[i+1]:
            repeat=library[i]
    return repeat

# Main function
rep
repeat=''
book_set = set()
print ('1 = add book')
print ('2 = add book to library')
print ('3 = remove book')
print ('4 = search book')
print ('5 = list all books book')
print ('6 = Categorize Books ')
print ('7 = check Duplicate Book ')
n=int(input('ENTER FUNCTION-NO. TO BE PERFORMED'))

# Adding books
if n==1:
    book1 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK1'),input('enter genre of BOOK1'))
    book2 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK2'),input('enter genre of BOOK2'))
    book3 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK3'),input('enter genre of BOOK3'))
    book4 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK4'),input('enter genre of BOOK4')) 
    print('Books added')
if n==2:
    library=[]
    add_to_library(book1, library, book_set)
    add_to_library(book2, library, book_set)
    add_to_library(book3, library, book_set)
    add_to_library(book4, library, book_set)  
    print(library)

# Removing a book
if n==3:
    remove_from_library(input('Book to remove'), library, book_set)

# Searching for books
if n==4:
    search_results = search_books(input('book to be searched'), library)
    print("Search results:",search_results)

#list all books
if n==5:
    list_books(library)

#categorize_books
if n==6:
    genre_dict = categorize_books(library)
    print(genre_dict)

if n==7:
    rep=()
    rep=check_dup(library) 
    print(rep)
# Out:
# 1 = add book
# 2 = add book to library
# 3 = remove book
# 4 = search book
# 5 = list all books book
# 6 = Categorize Books
# 7 = check Duplicate Book
# Book 'good deed' by zaid fun added to the library.
# Book 'bad deed' by mohd sad added to the library.
# Book 'pg story' by don none added to the library.
# Book 'pg story' by don already exists in the library.
# [('good deed', 'zaid', 'fun'), ('bad deed', 'mohd', 'sad'), ('pg story', 'don', 'none'), ('pg story', 'don', 'none')]

# %%
def add_book(title, author, genre):
    return (title, author, genre)

def add_to_library(book, library, book_set):
    if book not in book_set:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} {book[2]} added to the library.")
    else:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} already exists in the library.")
        return library

def remove_from_library(title, library, book_set):
    for book in library:
        if book[0] == title:
            library.remove(book)
            book_set.remove(book)
            print(f"Book '{title}' removed from the library.")
            return
    print(f"Book '{title}' not found in the library.")

def search_books(search_term, library):
    results = [book for book in library if search_term.lower() in book[0].lower() or search_term.lower() in book[1].lower()]
    return results

def list_books(library):
    if library:
        print("Entering in Library:")
        for i in range(len(library)):
                library[i]
                print(f"Title: {library[0]}, Author: {library[1]}, Genre: {library[2]}")
    else:
       print("No books in the library.")

def categorize_books(book, library, book_set):
    genre_dict = {}
    for book in library:
        genre = book[2]
        if genre not in genre_dict:
            genre_dict['genre'] = []
        genre_dict['genre'].append(book)
    return genre_dict

def check_dup(library):
    repeat=()
    for i in range(3):
        if library[i] == library[i+1]:
            repeat=library[i]
    return repeat

# Main function
rep
repeat=''
book_set = set()
print ('1 = add book')
print ('2 = add book to library')
print ('3 = remove book')
print ('4 = search book')
print ('5 = list all books book')
print ('6 = Categorize Books ')
print ('7 = check Duplicate Book ')
n=int(input('ENTER FUNCTION-NO. TO BE PERFORMED'))

# Adding books
if n==1:
    book1 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK1'),input('enter genre of BOOK1'))
    book2 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK2'),input('enter genre of BOOK2'))
    book3 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK3'),input('enter genre of BOOK3'))
    book4 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK4'),input('enter genre of BOOK4')) 
    print('Books added')
if n==2:
    library=[]
    add_to_library(book1, library, book_set)
    add_to_library(book2, library, book_set)
    add_to_library(book3, library, book_set)
    add_to_library(book4, library, book_set)  
    print(library)

# Removing a book
if n==3:
    remove_from_library(input('Book to remove'), library, book_set)

# Searching for books
if n==4:
    search_results = search_books(input('book to be searched'), library)
    print("Search results:",search_results)

#list all books
if n==5:
    list_books(library)

#categorize_books
if n==6:
    genre_dict = categorize_books(library)
    print(genre_dict)

if n==7:
    rep=()
    rep=check_dup(library) 
    print(rep)
# Out:
# 1 = add book
# 2 = add book to library
# 3 = remove book
# 4 = search book
# 5 = list all books book
# 6 = Categorize Books
# 7 = check Duplicate Book
# Entering in Library:
# Title: ('good deed', 'zaid', 'fun'), Author: ('bad deed', 'mohd', 'sad'), Genre: ('pg story', 'don', 'none')
# Title: ('good deed', 'zaid', 'fun'), Author: ('bad deed', 'mohd', 'sad'), Genre: ('pg story', 'don', 'none')
# Title: ('good deed', 'zaid', 'fun'), Author: ('bad deed', 'mohd', 'sad'), Genre: ('pg story', 'don', 'none')
# Title: ('good deed', 'zaid', 'fun'), Author: ('bad deed', 'mohd', 'sad'), Genre: ('pg story', 'don', 'none')

# %%
def add_book(title, author, genre):
    return (title, author, genre)

def add_to_library(book, library, book_set):
    if book not in book_set:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} {book[2]} added to the library.")
    else:
        library.append(book)
        book_set.add(book)
        print(f"Book '{book[0]}' by {book[1]} already exists in the library.")
        return library

def remove_from_library(title, library, book_set):
    for book in library:
        if book[0] == title:
            library.remove(book)
            book_set.remove(book)
            print(f"Book '{title}' removed from the library.")
            return
    print(f"Book '{title}' not found in the library.")

def search_books(search_term, library):
    results = [book for book in library if search_term.lower() in book[0].lower() or search_term.lower() in book[1].lower()]
    return results

def list_books(library):
    print("Entering in Library:")
    for i in range(4):
        library[i]
        print(f"Title: {library[0]}, Author: {library[1]}, Genre: {library[2]}")
    
    print("No books in the library.")

def categorize_books(book, library, book_set):
    genre_dict = {}
    for book in library:
        genre = book[2]
        if genre not in genre_dict:
            genre_dict['genre'] = []
        genre_dict['genre'].append(book)
    return genre_dict

def check_dup(library):
    repeat=()
    for i in range(3):
        if library[i] == library[i+1]:
            repeat=library[i]
    return repeat

# Main function
rep
repeat=''
book_set = set()
print ('1 = add book')
print ('2 = add book to library')
print ('3 = remove book')
print ('4 = search book')
print ('5 = list all books book')
print ('6 = Categorize Books ')
print ('7 = check Duplicate Book ')
n=int(input('ENTER FUNCTION-NO. TO BE PERFORMED'))

# Adding books
if n==1:
    book1 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK1'),input('enter genre of BOOK1'))
    book2 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK2'),input('enter genre of BOOK2'))
    book3 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK3'),input('enter genre of BOOK3'))
    book4 = add_book(input('enter BOOK_TITLE of BOOK1'),input('enter author of BOOK4'),input('enter genre of BOOK4')) 
    print('Books added')
if n==2:
    library=[]
    add_to_library(book1, library, book_set)
    add_to_library(book2, library, book_set)
    add_to_library(book3, library, book_set)
    add_to_library(book4, library, book_set)  
    print(library)

# Removing a book
if n==3:
    remove_from_library(input('Book to remove'), library, book_set)

# Searching for books
if n==4:
    search_results = search_books(input('book to be searched'), library)
    print("Search results:",search_results)

#list all books
if n==5:
    list_books(library)

#categorize_books
if n==6:
    genre_dict = categorize_books(library)
    print(genre_dict)

if n==7:
    rep=()
    rep=check_dup(library) 
    print(rep,'is DUPLICATE')
# Out:
# 1 = add book
# 2 = add book to library
# 3 = remove book
# 4 = search book
# 5 = list all books book
# 6 = Categorize Books
# 7 = check Duplicate Book
# ('pg story', 'don', 'none') is DUPLICATE
